# %% [markdown]
# <a href="https://colab.research.google.com/github/rizkiar00/Fuzzy-Logic/blob/master/Fuzzy_Logic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt; 
from google.colab import files
# %matplotlib inline
# !git clone https://github.com/rizkiar00/Fuzzy-Logic
# Out:
# fatal: destination path 'Fuzzy-Logic' already exists and is not an empty directory.

# %%
def gaji_kecil(x):
    L=1 #tinggi maks
    k=10 #seberapa belok
    a=0.5 #titik tengah
    return L/(1+np.exp(-k*(-x+a)))
        
def gaji_lumayan(x):
    a=1 #titik tengah
    w=0.2 #lebar
    return np.exp(-((x-a)/w)**2)
  
def gaji_lebih(x):
    L=1 #tinggi maks
    k=10 #seberapa belok
    a=1.5 #titik tengah
    return L/(1+np.exp(-k*(x-a)))

# %%
volume = np.arange(0,2, 0.01)
plt.plot(volume, gaji_kecil(volume), color='green', label='Kecil')
plt.plot(volume, gaji_lumayan(volume), color='blue', label='Lumayan')
plt.plot(volume, gaji_lebih(volume), color='red', label='Lebih')

plt.legend()
plt.title('Gaji')
plt.show()

# %%
def hutang_kecil(x):
    L=1 #tinggi maks
    k=0.25 #seberapa belok
    a=22.5 #titik tengah
    return L/(1+np.exp(-k*(-x+a)))
        
def hutang_lumayan(x):
    L = 1 #tinggi maks
    a=45 #titik tengah
    w=10 #lebar
    return L*np.exp(-((x-a)/w)**2)
  
def hutang_lebih(x):
    L=1 #tinggi maks
    k=0.25 #seberapa belok
    a=66.5 #titik tengah
    return L/(1+np.exp(-k*(x-a)))

# %%
volume = np.arange(0,90, 0.1)
plt.plot(volume, hutang_kecil(volume), color='green', label='Kecil')
plt.plot(volume, hutang_lumayan(volume), color='blue', label='Lumayan')
plt.plot(volume, hutang_lebih(volume), color='red', label='Lebih')

plt.legend()
plt.ylim(0, 1)
plt.title('Hutang')
plt.show()

# %%
def harta_kecil(x):
    L=1 #tinggi maks
    k=20 #seberapa belok
    a=0.25 #titik tengah
    return L/(1+np.exp(-k*(-x+a)))
        
def harta_lumayan(x):
    L = 1 #tinggi maks
    a=0.5 #titik tengah
    w=0.1 #lebar
    return L*np.exp(-((x-a)/w)**2)
  
def harta_lebih(x):
    L=1 #tinggi maks
    k=20 #seberapa belok
    a=0.75 #titik tengah
    return L/(1+np.exp(-k*(x-a)))

# %%
volume = np.arange(0,1, 0.01)
plt.plot(volume, harta_kecil(volume), color='green', label='Kecil')
plt.plot(volume, harta_lumayan(volume), color='blue', label='Lumayan')
plt.plot(volume, harta_lebih(volume), color='red', label='Lebih')

plt.legend()
plt.title('Harta')
plt.show()

# %%
def rule(gaji,g, hutang,h):
    if gaji == 'kecil' and hutang == 'kecil':
        return (np.minimum(g,h)) #lumayan
    elif gaji == 'kecil' and hutang == 'lumayan':
        return (np.minimum(g,h)) #kecil
    elif gaji == 'kecil' and hutang == 'lebih':
        return (np.minimum(g,h)) #lebih
    elif gaji == 'lumayan' and hutang == 'kecil':
        return (np.minimum(g,h)) #kecil
    elif gaji == 'lumayan' and hutang == 'lumayan':
        return (np.minimum(g,h)) #lumayan
    elif gaji == 'lumayan' and hutang == 'lebih':
        return (np.minimum(g,h)) #lebih
    elif gaji == 'lebih' and hutang == 'kecil':
        return (np.minimum(g,h)) #kecil
    elif gaji == 'lebih' and hutang == 'lumayan':
        return (np.minimum(g,h)) #lebih
    elif gaji == 'lebih' and hutang == 'lebih':
        return (np.minimum(g,h)) #lumayan

# %%
data = pd.read_csv('Fuzzy-Logic/DataTugas2.csv',skipinitialspace=True)
del data['No']
data
# Out:
#     Pendapatan  Hutang
# 0        1.632  39.375
# 1        0.825  39.236
# 2        1.273  80.701
# 3        1.534  73.641
# 4        1.596  37.319
# 5        0.664  63.226
# 6        1.680  37.761
# 7        0.925   0.000
# 8        0.806  69.192
# 9        1.178  26.359
# 10       1.548  53.764
# 11       1.617  55.544
# 12       0.890  41.718
# 13       1.354  61.333
# 14       0.428  38.739
# 15       1.319  41.201
# 16       0.859  26.266
# 17       1.345  76.343
# 18       0.599  45.566
# 19       1.763  55.289
# 20       0.155  29.496
# 21       0.828  56.747
# 22       0.112  26.202
# 23       0.819  60.764
# 24       1.723  33.533
# 25       1.410  25.133
# 26       1.255  27.166
# 27       1.369  50.779
# 28       1.684  45.068
# 29       1.794  24.110
# ..         ...     ...
# 70       1.046  13.541
# 71       1.641  46.775
# 72       0.158   1.472
# 73       0.600  80.864
# 74       0.894  22.836
# 75       0.791  39.781
# 76       1.217  82.991
# 77       1.900  32.769
# 78       1.227  20.851
# 79       0.664  39.692
# 80       1.164  18.112
# 81       1.804  27.693
# 82       0.219  11.550
# 83       1.643  57.308
# 84       1.030  25.246
# 85       1.531  21.480
# 86       1.593  41.325
# 87       1.209  67.625
# 88       0.754  37.883
# 89       1.586  38.999
# 90       0.793  11.302
# 91       0.817  62.427
# 92       0.557  29.517
# 93       1.474  56.534
# 94       1.329  71.308
# 95       0.910  43.769
# 96       0.950  23.790
# 97       1.406  46.838
# 98       0.816  18.123
# 99       1.183  28.061
#
# [100 rows x 2 columns]

# %%
gkecil = []
glumayan = []
glebih = []
hkecil = []
hlumayan = []
hbesar = []
for index, row in data.iterrows():
    gkecil.append(gaji_kecil(row['Pendapatan']))
    glumayan.append(gaji_lumayan(row['Pendapatan']))
    glebih.append(gaji_lebih(row['Pendapatan']))
    hkecil.append(hutang_kecil(row['Hutang']))
    hlumayan.append(hutang_lumayan(row['Hutang']))
    hbesar.append(hutang_lebih(row['Hutang']))
#     fuzzy_output.append(data)
d = {'gkecil': gkecil, 'glumayan': glumayan, 'glebih':glebih, 'hkecil':hkecil, 'hlumayan':hlumayan, 'hbesar':hbesar}
fuzzy_output = pd.DataFrame(data=d)
fuzzy_output = fuzzy_output[['gkecil', 'glumayan', 'glebih', 'hkecil', 'hlumayan', 'hbesar']]
fuzzy_output
# Out:
#           gkecil      glumayan        glebih        hkecil      hlumayan  \
# 0   1.212778e-05  4.605842e-05  7.891817e-01  1.450358e-02  7.287633e-01
# 1   3.732689e-02  4.650432e-01  1.169510e-03  1.500874e-02  7.173173e-01
# 2   4.392511e-04  1.551714e-01  9.363821e-02  4.796302e-07  2.915078e-06
# 86  1.844409e-03
# 87  5.698527e-01
# 88  7.809252e-04
# 89  1.031973e-03
# 90  1.016138e-06
# 91  2.653684e-01
# 92  9.651168e-05
# 93  7.645621e-02
# 94  7.688804e-01
# 95  3.392635e-03
# 96  2.305742e-05
# 97  7.278683e-03
# 98  5.591541e-06
# 99  6.706709e-05
#
# [100 rows x 6 columns]

# %%
hakecil = []
halumayan = []
halebih = []
for index, row in fuzzy_output.iterrows():
    hakecil.append(max(rule('kecil',row['gkecil'],'lumayan',row['hlumayan']),rule('lumayan',row['glumayan'],'lebih',row['glebih'])))
    halumayan.append(max(rule('kecil',row['gkecil'],'kecil',row['hkecil']),rule('kecil',row['gkecil'],'lebih',row['glebih']),
                        rule('lumayan',row['glumayan'],'lumayan',row['hlumayan']),rule('lebih',row['glebih'],'kecil',row['hkecil']),
                                rule('lebih',row['glebih'],'lebih',row['glebih'])))
    halebih.append(max(rule('lebih',row['glebih'],'lumayan',row['hlumayan']),rule('lumayan',row['glumayan'],'kecil',row['gkecil'])))
    fuzzy_output.insert()
d = {'hakecil':hakecil, 'halumayan':halumayan, 'halebih':halebih}
output = pd.DataFrame(data=d)
output = output[['hakecil', 'halumayan', 'halebih']]
output
# Out:
#          hakecil  halumayan       halebih
# 0   4.605842e-05   0.789182  7.287633e-01
# 1   3.732689e-02   0.465043  3.732689e-02
# 2   9.363821e-02   0.093638  4.392511e-04
# 3   8.016007e-04   0.584191  2.738120e-04
# 4   1.390885e-04   0.723122  5.543397e-01
# 5   3.608526e-02   0.036085  5.946306e-02
# 6   9.540163e-06   0.858149  5.921287e-01
# 7   3.172683e-03   0.014064  1.406363e-02
# 8   2.872626e-03   0.002873  4.478770e-02
# 9   3.841999e-02   0.038420  3.096590e-02
# 10  5.488969e-04   0.617748  4.639043e-01
# 11  7.357355e-05   0.763145  3.289797e-01
# 12  1.984031e-02   0.738968  1.984031e-02
# 13  4.359120e-02   0.188467  6.941385e-02
# 14  6.726070e-01   0.016961  2.803140e-04
# 15  7.854960e-02   0.140638  1.406381e-01
# 16  2.685712e-02   0.029908  2.685712e-02
# 17  5.101554e-02   0.175086  2.138547e-04
# 18  2.709121e-01   0.017953  1.795252e-02
# 19  3.272346e-06   0.932768  3.469290e-01
# 20  9.037929e-02   0.148173  1.441248e-06
# 21  3.626372e-02   0.251599  3.626372e-02
# 22  2.919821e-02   0.283839  9.375451e-07
# 23  3.954378e-02   0.083322  3.954378e-02
# 24  4.881759e-06   0.902911  2.684956e-01
# 25  1.495813e-02   0.289050  1.931300e-02
# 26  7.943855e-02   0.079439  4.156422e-02
# 27  3.323921e-02   0.212487  2.124868e-01
# 28  8.323731e-06   0.862949  8.629487e-01
# 29  2.400095e-06   0.949789  1.272838e-02
# ..           ...        ...           ...
# 70  1.056069e-02   0.010561  4.235540e-03
# 71  3.458727e-05   0.803766  8.037659e-01
# 72  2.006879e-08   0.968324  2.006879e-08
# 73  1.233946e-04   0.000123  1.831564e-02
# 74  7.354603e-03   0.019077  1.907720e-02
# 75  5.166144e-02   0.335536  5.166144e-02
# 76  5.572440e-02   0.055724  7.687313e-04
# 77  8.315280e-07   0.982014  2.240304e-01
# 78  6.122616e-02   0.061226  2.932963e-03
# 79  1.624651e-01   0.059463  5.946306e-02
# 80  3.356922e-02   0.033569  1.305321e-03
# 81  2.171696e-06   0.954349  5.002049e-02
# 82  1.382510e-05   0.939204  2.733295e-06
# 83  3.243654e-05   0.806901  2.198371e-01
# 84  9.013299e-03   0.020197  9.013299e-03
# 85  8.682551e-04   0.576885  3.958445e-03
# 86  1.520616e-04   0.717075  7.170753e-01
# 87  5.166144e-02   0.051661  5.982563e-03
# 88  7.310117e-02   0.220270  7.310117e-02
# 89  1.869069e-04   0.702661  6.975926e-01
# 90  8.495108e-04   0.050690  5.069032e-02
# 91  4.031042e-02   0.047978  4.031042e-02
# 92  9.096933e-02   0.147512  7.400372e-03
# 93  3.635895e-03   0.435364  2.643896e-01
# 94  6.680182e-02   0.153164  9.867354e-04
# 95  1.630250e-02   0.816686  1.630250e-02
# 96  1.098694e-02   0.011124  1.098694e-02
# 97  1.622990e-02   0.280900  2.809003e-01
# 98  1.068960e-03   0.040699  4.069905e-02
# 99  4.031042e-02   0.056739  4.031042e-02
#
# [100 rows x 3 columns]

# %%
nilaiharta = []
for index, row in output.iterrows():
  nilaiharta.append(1*row['hakecil']+2*row['halumayan']+3*row['halebih'])
d = {'nilaiharta':nilaiharta}
hasil_defuzifikasi = pd.DataFrame(data=d)
urut = hasil_defuzifikasi.sort_values(by=['nilaiharta'])
urut
# Out:
#     nilaiharta
# 70    0.044389
# 35    0.046024
# 73    0.055317
# 96    0.066196
# 43    0.067889
# 60    0.071720
# 7     0.073491
# 84    0.076448
# 61    0.100070
# 74    0.102741
# 80    0.104624
# 40    0.110264
# 8     0.142981
# 16    0.167245
# 76    0.169479
# 68    0.171042
# 87    0.172932
# 46    0.174211
# 78    0.192477
# 98    0.204564
# 9     0.208158
# 69    0.240345
# 90    0.254301
# 91    0.257199
# 99    0.274719
# 2     0.282232
# 5     0.286645
# 23    0.324820
# 53    0.359375
# 18    0.360675
# ..         ...
# 85    1.166514
# 3     1.170004
# 32    1.176792
# 97    1.420732
# 12    1.557298
# 93    1.667532
# 95    1.698583
# 82    1.878429
# 72    1.936648
# 29    1.937765
# 44    1.960092
# 81    2.058761
# 83    2.273346
# 11    2.513303
# 24    2.611314
# 10    2.627758
# 77    2.636120
# 19    2.906325
# 4     3.109402
# 51    3.124538
# 45    3.228529
# 6     3.492694
# 89    3.498286
# 86    3.585528
# 0     3.764699
# 54    3.869154
# 71    4.018864
# 28    4.314752
# 49    4.341751
# 36    4.604301
#
# [100 rows x 1 columns]

# %%
terkecil = urut.drop(urut.index[20:100])
del terkecil['nilaiharta']
terkecil
# Out:
# Empty DataFrame
# Columns: []
# Index: [70, 35, 73, 96, 43, 60, 7, 84, 61, 74, 80, 40, 8, 16, 76, 68, 87, 46, 78, 98]

# %%
terkecil.to_csv('TebakanTugas2.csv', sep='\t', encoding='utf-8',header=None)
files.download('TebakanTugas2.csv')
